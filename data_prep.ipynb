# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
pd.set_option("display.max_columns",None)

# %%
dataset=pd.read_csv("C:/users/daniel/documents/edureka/house prices/train.csv")

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
dataset=dataset.drop(columns="Id")

# %% [markdown]
# ### A. Extract the number of columns/features that have null values

# %%
for i in dataset.columns:
    if dataset[i].isnull().sum()>0:
        print(i, dataset[i].dtypes)
# Out:
# LotFrontage float64
# Alley object
# MasVnrType object
# MasVnrArea float64
# BsmtQual object
# BsmtCond object
# BsmtExposure object
# BsmtFinType1 object
# BsmtFinType2 object
# Electrical object
# FireplaceQu object
# GarageType object
# GarageYrBlt float64
# GarageFinish object
# GarageQual object
# GarageCond object
# PoolQC object
# Fence object
# MiscFeature object

# %% [markdown]
# #### Rewrite the above code in list comprehension format

# %%
null_features=[i for i in dataset.columns if dataset[i].isnull().sum()>0]

null_features
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %% [markdown]
# ### Ai. What is the relationship between the missing values and sales price
#
# ### How did the missing values affect the average Sales price

# %%
for i in null_features:
    
    data= dataset.copy()
    data[i]=np.where(data[i].isnull(),1,0)
    
    data.groupby([i])["SalePrice"].median().plot(kind="bar")
    plt.show()

# %% [markdown]
# ##### We see that the null values had a big effect on the average sales price

# %% [markdown]
# # 1. Numerical Features

# %%
num_feat=[i for i in dataset.columns if dataset[i].dtypes !="O"]

print(dataset[num_feat].shape)
dataset[num_feat].head()
# Out:
# (1460, 37)
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
#dataset[num_feat].isnull().sum()

# %%
yearfeat=[i for i in num_feat if "Yr" in i or "Year" in i]

yearfeat
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for i in yearfeat:
    graph=data.groupby([i])["SalePrice"].median().plot(kind="line")
    plt.show()

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %% [markdown]
# ### 1a. Discrete Numerical Features i.e Features with unqiue values less than 25

# %%
discrete_feat=[i for i in num_feat if len(dataset[i].unique())<25 and i not in yearfeat]

print(dataset[discrete_feat].shape)
dataset[discrete_feat].head()
# Out:
# (1460, 17)
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
dataset[discrete_feat].isnull().sum()
# Out:
# MSSubClass      0
# OverallQual     0
# OverallCond     0
# LowQualFinSF    0
# BsmtFullBath    0
# BsmtHalfBath    0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# KitchenAbvGr    0
# TotRmsAbvGrd    0
# Fireplaces      0
# GarageCars      0
# 3SsnPorch       0
# PoolArea        0
# MiscVal         0
# MoSold          0
# dtype: int64

# %% [markdown]
# #### Let us count the number of unique values in the discrete features

# %%
for i in dataset[discrete_feat]:
    print(len(dataset[i].unique()))
# Out:
# 15
# 10
# 9
# 24
# 4
# 3
# 4
# 3
# 8
# 4
# 12
# 4
# 5
# 20
# 8
# 21
# 12

# %%
for i in dataset[discrete_feat]:
    print(dataset[i].value_counts(dropna=False))
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64
# 5    821
# 6    252
# 7    205
# 8     72
# 4     57
# 3     25
# 9     22
# 2      5
# 1      1
# Name: OverallCond, dtype: int64
# 0      1434
# 80        3
# 360       2
# 528       1
# 53        1
# 120       1
# 144       1
# 156       1
# 205       1
# 232       1
# 234       1
# 371       1
# 572       1
# 390       1
# 392       1
# 397       1
# 420       1
# 473       1
# 479       1
# 481       1
# 513       1
# 514       1
# 515       1
# 384       1
# Name: LowQualFinSF, dtype: int64
# 0    856
# 1    588
# 2     15
# 3      1
# Name: BsmtFullBath, dtype: int64
# 0    1378
# 1      80
# ...

# %% [markdown]
# #### 1ai. Find the relationship between the Discrete features and Price

# %%
for i in dataset[discrete_feat]:
    dataset.groupby([i])["SalePrice"].median().plot(kind="bar")
    plt.xlabel(i)
    plt.ylabel("Price")
    plt.show()

# %% [markdown]
# ##### There are relationships between the discrete features and price

# %% [markdown]
# ### 1b. Continous Numerical Features i.e Features with unqiue values more than 25

# %%
continous_feat=[i for i in num_feat if i not in discrete_feat and i not in yearfeat]

print(dataset[continous_feat].shape)
dataset[continous_feat].head()
# Out:
# (1460, 16)
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# ...

# %%
dataset[continous_feat].isnull().sum()
# Out:
# LotFrontage      259
# LotArea            0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# ScreenPorch        0
# SalePrice          0
# dtype: int64

# %% [markdown]
# #### 1bi. Find the relationship between the Continous features and Price

# %%
for i in dataset[continous_feat]:
    
    dataset[i].hist(bins=25)
    plt.xlabel(i)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ##### From the above analysis, we see that most of the graphs do not follow normal distribution.
# ###### So, we need to transform the data

# %% [markdown]
# ##### 1bii. We wil be using logarithmic transformation

# %%
for i in continous_feat:
    data=dataset.copy()
    if 0 in data[i].unique():
        pass
    else:
        data[i]=np.log(data[i])
        
        data[i].hist(bins=25)
        plt.ylabel("Count")
        plt.xlabel(i)
        plt.show()

# %% [markdown]
# ## 1biii. Let us check for Outliers

# %%
for i in continous_feat:
    data=dataset.copy()
    if 0 in data[i].unique():
        pass
    else:
        data[i]=np.log(data[i])
        
        data.boxplot(column=i)
        plt.ylabel("Count")
        plt.xlabel(i)
        plt.show()

# %%
for i in continous_feat:
    data.boxplot(column=i)
    plt.ylabel("Count")
    plt.xlabel(i)
    plt.show()

# %% [markdown]
# # 2. Categorical Variables

# %%
cat_feat=[i for i in dataset.columns if i not in num_feat]

print(dataset[cat_feat].shape)
dataset[cat_feat].head()
# Out:
# (1460, 43)
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
count_ofvar=[(i,len(dataset[i].unique())) for i in cat_feat]

count_ofvar
# Out:
# [('MSZoning', 5),
#  ('Street', 2),
#  ('Alley', 3),
#  ('LotShape', 4),
#  ('LandContour', 4),
#  ('Utilities', 2),
#  ('LotConfig', 5),
#  ('LandSlope', 3),
#  ('Neighborhood', 25),
#  ('Condition1', 9),
#  ('Condition2', 8),
#  ('BldgType', 5),
#  ('HouseStyle', 8),
#  ('RoofStyle', 6),
#  ('RoofMatl', 8),
#  ('Exterior1st', 15),
#  ('Exterior2nd', 16),
#  ('MasVnrType', 5),
#  ('ExterQual', 4),
#  ('ExterCond', 5),
#  ('Foundation', 6),
#  ('BsmtQual', 5),
#  ('BsmtCond', 5),
#  ('BsmtExposure', 5),
#  ('BsmtFinType1', 7),
#  ('BsmtFinType2', 7),
#  ('Heating', 6),
#  ('HeatingQC', 5),
#  ('CentralAir', 2),
#  ('Electrical', 6),
#  ('KitchenQual', 4),
#  ('Functional', 7),
#  ('FireplaceQu', 6),
#  ('GarageType', 7),
#  ('GarageFinish', 4),
#  ('GarageQual', 6),
#  ('GarageCond', 6),
#  ('PavedDrive', 3),
#  ('PoolQC', 4),
#  ('Fence', 5),
#  ('MiscFeature', 5),
#  ('SaleType', 9),
#  ('SaleCondition', 6)]

# %% [markdown]
# #### 2a. Find the relationship between the Categorical features and Price

# %%
for i in cat_feat:
    
    dataset.groupby([i])["SalePrice"].median().plot(kind="bar")
    plt.ylabel("Price")
    plt.show()

# %% [markdown]
# # 3. Feature Engineering
#
# ### Do a Train-Test-Split

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

from sklearn.model_selection import train_test_split as tts

trainx,testx,trainy,testy = tts(x,y,test_size=0.2, random_state=1)

# %% [markdown]
# # Handle the missing values

# %% [markdown]
# ##### 3a. Missing values in the Categorical features

# %%
cat_null=[i for i in cat_feat if dataset[i].isnull().sum()>0]

# %%
catnull=[(i, dataset[i].isnull().sum()) for i in cat_feat if dataset[i].isnull().sum()>0]
catnull
# Out:
# [('Alley', 1369),
#  ('MasVnrType', 8),
#  ('BsmtQual', 37),
#  ('BsmtCond', 37),
#  ('BsmtExposure', 38),
#  ('BsmtFinType1', 37),
#  ('BsmtFinType2', 38),
#  ('Electrical', 1),
#  ('FireplaceQu', 690),
#  ('GarageType', 81),
#  ('GarageFinish', 81),
#  ('GarageQual', 81),
#  ('GarageCond', 81),
#  ('PoolQC', 1453),
#  ('Fence', 1179),
#  ('MiscFeature', 1406)]

# %%
for i in cat_null:
        dataset[i]=dataset[i].fillna("Missing")

# %%
dataset[cat_null].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# ##### 3b. Missing values in the discrete num features

# %%
dataset[discrete_feat].isnull().sum()
# Out:
# MSSubClass      0
# OverallQual     0
# OverallCond     0
# LowQualFinSF    0
# BsmtFullBath    0
# BsmtHalfBath    0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# KitchenAbvGr    0
# TotRmsAbvGrd    0
# Fireplaces      0
# GarageCars      0
# 3SsnPorch       0
# PoolArea        0
# MiscVal         0
# MoSold          0
# dtype: int64

# %% [markdown]
# ##### No null values are present

# %% [markdown]
# ##### 3c. Missing values in the continous num features

# %%
dataset[continous_feat].isnull().sum()
# Out:
# LotFrontage      259
# LotArea            0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# GrLivArea          0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# ScreenPorch        0
# SalePrice          0
# dtype: int64

# %%
for i in continous_feat:
    dataset[i]=dataset[i].fillna(dataset[i].median())

# %% [markdown]
# ##### 3d. Missing values in the year features

# %%
for i in yearfeat:
    if i != "YrSold":
        dataset[i]=dataset["YrSold"]-dataset[i]
    else:
        pass

# %%
dataset["GarageYrBlt"]=dataset["GarageYrBlt"].fillna(dataset["GarageYrBlt"].median())

# %%
dataset.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Missing      Reg
# 1          20       RL         80.0     9600   Pave  Missing      Reg
# 2          60       RL         68.0    11250   Pave  Missing      IR1
# 3          70       RL         60.0     9550   Pave  Missing      IR1
# 4          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # 4. Normalize the data

# %%
data[continous_feat].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  GarageArea  WoodDeckSF  \
# 0          856       856       854       1710         548           0
# 1         1262      1262         0       1262         460         298
# 2          920       920       866       1786         608           0
# 3          756       961       756       1717         642           0
# 4         1145      1145      1053       2198         836         192
#
#    OpenPorchSF  EnclosedPorch  ScreenPorch  SalePrice
# 0           61              0            0  12.247694
# ...

# %%
for i in continous_feat:
    if 0 in dataset[i].unique():
        pass
    else:
        dataset[i]=np.log(dataset[i])
        
        dataset[i].hist(bins=25)
        plt.ylabel("Count")
        plt.xlabel(i)
        plt.show()

# %%
dataset.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape  \
# 0          60       RL     4.174387  9.041922   Pave  Missing      Reg
# 1          20       RL     4.382027  9.169518   Pave  Missing      Reg
# 2          60       RL     4.219508  9.328123   Pave  Missing      IR1
# 3          70       RL     4.094345  9.164296   Pave  Missing      IR1
# 4          60       RL     4.430817  9.565214   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## 5. Label Encoding

# %%
for i in cat_feat:
    catrank=dataset.groupby([i])["SalePrice"].mean().sort_values().index
    catmap={y:x for x,y in enumerate(catrank,0)}
    dataset[i]=dataset[i].map(catmap)

# %%
catrank
# Out:
# Index(['AdjLand', 'Abnorml', 'Family', 'Alloca', 'Normal', 'Partial'], dtype='object', name='SaleCondition')

# %%
dataset.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0          60         3     4.174387  9.041922       1      2         0
# 1          20         3     4.382027  9.169518       1      2         0
# 2          60         3     4.219508  9.328123       1      2         1
# 3          70         3     4.094345  9.164296       1      2         1
# 4          60         3     4.430817  9.565214       1      2         1
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            1          1          0          0            15           3
# 1            1          1          2          0            20           1
# 2            1          1          0          0            15           3
# 3            1          1          1          0            17           3
# 4            1          1          2          0            24           3
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # 6. Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

mms=MinMaxScaler()
data1=mms.fit_transform(dataset.drop(columns="SalePrice"))
data1
# Out:
# array([[0.23529412, 0.75      , 0.41820812, ..., 0.5       , 0.5       ,
#         0.8       ],
#        [0.        , 0.75      , 0.49506375, ..., 0.25      , 0.5       ,
#         0.8       ],
#        [0.23529412, 0.75      , 0.434909  , ..., 0.5       , 0.5       ,
#         0.8       ],
#        ...,
#        [0.29411765, 0.75      , 0.42385922, ..., 1.        , 0.5       ,
#         0.8       ],
#        [0.        , 0.75      , 0.434909  , ..., 1.        , 0.5       ,
#         0.8       ],
#        [0.        , 0.75      , 0.47117546, ..., 0.5       , 0.5       ,
#         0.8       ]])

# %%
col=dataset.drop(columns="SalePrice").columns

# %%
#col

# %%
datas=pd.concat([pd.DataFrame(data1,columns=col),dataset["SalePrice"]],axis=1)

# %%
datas.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape  \
# 0    0.235294      0.75     0.418208  0.366344     1.0    1.0  0.000000
# 1    0.000000      0.75     0.495064  0.391317     1.0    1.0  0.000000
# 2    0.235294      0.75     0.434909  0.422359     1.0    1.0  0.333333
# 3    0.294118      0.75     0.388581  0.390295     1.0    1.0  0.333333
# 4    0.235294      0.75     0.513123  0.468761     1.0    1.0  0.333333
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0     0.333333        1.0       0.00        0.0      0.625000       0.375
# 1     0.333333        1.0       0.50        0.0      0.833333       0.125
# 2     0.333333        1.0       0.00        0.0      0.625000       0.375
# 3     0.333333        1.0       0.25        0.0      0.708333       0.375
# 4     0.333333        1.0       0.50        0.0      1.000000       0.375
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# # 7. Feature Selection

# %%
from sklearn.linear_model import Lasso

from sklearn.feature_selection import SelectFromModel

# %%
x=datas.iloc[:,:-1]

y=data.iloc[:,-1]

# %%
for i in x.columns:
    print(i,x[i].isnull().sum())
# Out:
# MSSubClass 0
# MSZoning 0
# LotFrontage 0
# LotArea 0
# Street 0
# Alley 0
# LotShape 0
# LandContour 0
# Utilities 0
# LotConfig 0
# LandSlope 0
# Neighborhood 0
# Condition1 0
# Condition2 0
# BldgType 0
# HouseStyle 0
# OverallQual 0
# OverallCond 0
# YearBuilt 0
# YearRemodAdd 0
# RoofStyle 0
# RoofMatl 0
# Exterior1st 0
# Exterior2nd 0
# MasVnrType 0
# MasVnrArea 0
# ExterQual 0
# ExterCond 0
# Foundation 0
# BsmtQual 0
# BsmtCond 0
# BsmtExposure 0
# BsmtFinType1 0
# BsmtFinSF1 0
# BsmtFinType2 0
# BsmtFinSF2 0
# BsmtUnfSF 0
# TotalBsmtSF 0
# Heating 0
# HeatingQC 0
# CentralAir 0
# Electrical 0
# 1stFlrSF 0
# 2ndFlrSF 0
# LowQualFinSF 0
# GrLivArea 0
# BsmtFullBath 0
# BsmtHalfBath 0
# FullBath 0
# HalfBath 0
# BedroomAbvGr 0
# KitchenAbvGr 0
# KitchenQual 0
# TotRmsAbvGrd 0
# Functional 0
# Fireplaces 0
# FireplaceQu 0
# GarageType 0
# GarageYrBlt 0
# GarageFinish 0
# GarageCars 0
# GarageArea 0
# GarageQual 0
# GarageCond 0
# PavedDrive 0
# WoodDeckSF 0
# OpenPorchSF 0
# ...

# %%
model=SelectFromModel(Lasso(alpha=0.005,random_state=0))

model.fit(x,y)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.005, random_state=0))

# %%
selected_col=x.columns[model.get_support()]

# %%
selected_col.shape
# Out:
# (18,)

# %%
x.shape
# Out:
# (1460, 79)

# %%
selected_col
# Out:
# Index(['MSSubClass', 'Neighborhood', 'OverallQual', 'YearRemodAdd', 'BsmtQual',
#        'BsmtExposure', 'HeatingQC', 'CentralAir', '1stFlrSF', 'GrLivArea',
#        'BsmtFullBath', 'KitchenQual', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageFinish', 'GarageCars', 'SaleCondition'],
#       dtype='object')

# %%
x[selected_col].head()
# Out:
#    MSSubClass  Neighborhood  OverallQual  YearRemodAdd  BsmtQual  \
# 0    0.235294      0.625000     0.666667      0.098361      0.75
# 1    0.000000      0.833333     0.555556      0.524590      0.75
# 2    0.235294      0.625000     0.666667      0.114754      0.75
# 3    0.294118      0.708333     0.666667      0.606557      0.50
# 4    0.235294      1.000000     0.777778      0.147541      0.75
#
#    BsmtExposure  HeatingQC  CentralAir  1stFlrSF  GrLivArea  BsmtFullBath  \
# 0          0.25       1.00         1.0  0.356155   0.577712      0.333333
# 1          1.00       1.00         1.0  0.503056   0.470245      0.000000
# 2          0.50       1.00         1.0  0.383441   0.593095      0.333333
# 3          0.25       0.75         1.0  0.399941   0.579157      0.333333
# 4          0.75       1.00         1.0  0.466237   0.666523      0.333333
#
#    KitchenQual  Fireplaces  FireplaceQu  GarageType  GarageFinish  GarageCars  \
# ...
